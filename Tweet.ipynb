# %%
import tweepy
from twitter import Twitter, OAuth, TwitterHTTPError
from tweepy import OAuthHandler
import time
import random

consumer_key = ''
consumer_secret = ''
access_token = ''
access_secret = ''

t = Twitter(auth=OAuth(access_token, access_secret,
            consumer_key, consumer_secret))


auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
while True:
    try:
        for status in tweepy.Cursor(api.home_timeline).items():
            print(status.id,status.user.id,status.user.name,status.created_at,status.lang,status.favorite_count,status.retweet_count,status.text)
    except tweepy.TweepError:
        time.sleep(60 * 15)
        continue
    except StopIteration:
        break

# %%
print(api.get_user("narendramodi").id)

# %%
for i in api.rate_limit_status()['resources']:
    print(i)print(api.rate_limit_status()['resources'])

# %%
# get user timeline
page = 1
index=1
count=0
while True:
    if count<600:
        statuses = api.user_timeline(user_id=api.get_user("narendramodi").id,page=page)
        if statuses:
            for status in statuses:
                print(str(index)+","+str(status.id)+","+
                      str(status.user.id)+","+
                      str(status.user.name)+","+
                      str(status.created_at)+","+
                      str(status.lang)+","+
                      str(status.favorite_count)+","+
                      str(status.retweet_count)+","+
                      str(status.text.replace(","," ")))
                index +=1
        else:
            break
        page += 1 
        count +=1
    if count==600:
        count=0
        time.sleep(60 * 15)

# %%
#timeline

index=1
while True:
    try:
        for status in tweepy.Cursor(api.user_timeline(user_id=api.get_user("narendramodi").id)).items():
            print(index,status.id,status.user.id,status.user.name,status.created_at,status.lang,status.favorite_count,status.retweet_count,status.text)
            index=index+1
    except tweepy.TweepError:
        print("wait")
        time.sleep(60 * 15)
        continue
        
    except StopIteration:
        break

# %%
#reply

i=1
query="Good Evening"
while True:
    try:
        for status in tweepy.Cursor(api.search, q=query).items(10): 
            tweet = 'Good Evening! @'+status.user.screen_name
            statusid = status.id
            api.update_status(status=tweet, in_reply_to_status_id=status.id)
            print(i,tweet,status.id)
            i += 1
    except tweepy.TweepError:
        print("wait")
        time.sleep(60 * 15)
        continue
        
    except StopIteration:
        break

# %%
#follow

i=1
query="abu ismail"

while True:
    try:
        for status in tweepy.Cursor(api.search, q=query).items(): 
            api.create_friendship(screen_name = status.user.screen_name)
            check=False
            if(check == False):
                t.mutes.users.create(user_id=status.user.id)
                print(i,status.user.screen_name)
                n=int(random.uniform(1, 9))
                time.sleep(n)
                i += 1
    except tweepy.TweepError:
        print("wait")
        time.sleep(60 * 15)
        continue
        
    except StopIteration:
        break
# Out:
# 1 ravinder_4125
# 2 DurjanAndTrikal
# 3 TwittySant
# 4 Sachin5653Patel
# 5 kartikhldbjp
# 6 No1TVChannel
# 7 behl_neelu
# 8 RicksonPereira9
# 9 ShivAroor
# 10 SaahilSuhail
# 11 Milan_Parekh347
# 12 RPujary
# 13 nilleo007
# 14 dsn0912
# 15 sangameshtotapp
# 16 jewish_indian
# 17 ganapati23
# 18 RajeshKumarMor8
# 19 roshnichatarje
# 20 ajinkya_shevate
# 21 coolrealpk
# 22 Bawachi64
# 23 RiisshhiiRishi
# 24 narakehayat
# 25 Sandeep75178616
# 26 itheabhijeet
# 27 Hitesh36080919
# 28 mohitjha7966
# 29 tweetkhyati
# 30 montu1207
# 31 anandhardas
# 32 Ramjasia
# 33 ta0i5t
# 34 aramazad12
# 35 vishnu_moholkar
# 36 kkolge
# 37 LohiyaMeghraj
# 38 LivePulwama
# 39 amityadavamit
# 40 gk_thehindutva
# 41 ayushniftian
# 42 SANJAYGHARMALKA
# 43 ajitshah0482
# 44 Gaurav_5505
# 45 satyaprakashty1
# 46 dhruvbhim
# 47 CAABTRI
# 48 snehils1994
# 49 RoflHaryanvi_
# 50 GautiNK
# 51 sukkhisandhu
# 52 tapanpokar
# 53 ashutosh_nov12
# 54 KandarpMistry
# 55 IndiaToday
# 56 sorry_saktimaan
# 57 thustiaatma
# 58 kalpeshmgandhi
# 59 montu1207
# 60 sorry_saktimaan
# 61 ggiittiikkaa
# 62 NamoModiBhakt
# 63 UrviDM
# 64 rakx80
# 65 SSSharma11111
# 66 drpwndutta
# 67 Saurabh_3598
# 68 Sachin5653Patel
# 69 jewish_indian
# 70 Voice_of_Ranjan
# 71 pp5686
# 72 DS__Rajput
# 73 Abhi14267
# 74 RPratap565
# 75 ViralVaishnav2
# 76 AllegedLowbrow
# 77 debasishansda
# 78 MITHILE96150074
# 79 morkar_aniket
# 80 satyaprakashty1
# 81 OyePakistani
# 82 kamalnayanrai3
# 83 PulkitGola
# 84 moyaagarwal
# 85 prajob
# 86 bb69959
# 87 moyaagarwal
# 88 BhattHarshdip
# 89 Lauh_purush
# 90 ahirya
# 91 KanotraHarish
# 92 Krantipetkar1
# 93 Kirak_Admi
# 94 bbbishnu1995
# 95 Sachin5653Patel
# 96 JaiswarOne
# 97 Rajendradass
# 98 EshwarT1234
# 99 pandeythinks
# 100 bbbishnu1995
# 101 EshwarT1234
# 102 kaushik_suneet
# 103 Pramod_DS
# 104 devanghexa
# 105 ved007pkh
# 106 RohitSekhri
# 107 EshwarT1234
# 108 ddgautam
# 109 Prakash80254724
# 110 rusty4747
# 111 AnurodhLal
# 112 vinayak_ghate
# 113 modis_feed
# 114 proud_2beIndian
# 115 UPwala_Thakur
# 116 sunnyp192
# 117 goodguyrohit
# 118 avsbhadwal
# 119 HardlineHindu
# 120 Yogi210875
# 121 CoffeePenCamera
# 122 YGaurav_
# 123 PostKob
# 124 Oh_fame_
# 125 arjun_pandit_
# 126 4ffbd38e9d3044b
# 127 AbhinavSharmaa5
# 128 SentextS
# 129 JoshiRakesh2004
# 130 Sanjeev62560795
# 131 sarma_roni
# 132 arpitjain0141
# 133 vaibansal
# 134 ChKashifAli
# 135 RaphaelStonem
# 136 HelleNico
# 137 Yashkin5
# 138 iuripohl
# 139 MobilityStone
# 140 withdavidavritt
# 141 biswajitnath89
# 142 AjitHegade
# 143 vijendr27894580
# 144 PulkitGola
# 145 chelseamckm
# 146 Sachin5653Patel
# 147 RadioWaba
# 148 globnewsen
# 149 Booutique
# 150 globnewsen
# 151 redeyethug
# 152 ChetanV1623
# 153 globnewsen
# 154 AHA1R
# 155 Herzukka
# 156 rkbpillai
# 157 globnewsen
# 158 globnewsen
# 159 Arturo8574
# 160 JeffHickman14
# 161 dsandidge99
# 162 ButterflySnrida
# 163 NowOrange
# 164 Master_Logician
# 165 papers_int
# 166 nereuvjr
# 167 attilabokor
# 168 smarthere
# 169 proudIndian2024
# 170 VenkataGiriapp2
# 171 crewislife
# 172 kiran22006
# 173 mobeenchughtai
# 174 pressshare
# 175 RichTVXAsia
# 176 Bertotxu
# 177 UKLuxForYou
# 178 luvthemstillers
# 179 Flash_Feed
# 180 EIS_Agency
# 181 brooklynnycmike
# 182 kundacoffee
# 183 GeoffRogersEU
# 184 1milhaodetweets
# 185 TheLurknews
# 186 PanLexFirm
# 187 Greg_Burstock
# 188 gus_otto
# 189 TDailyNew1
# 190 cbelive_com
# 191 jozbanski
# 192 atif_a_akram
# 193 eng_moe_a
# 194 SoniyaRatnakar
# 195 ugossip1
# 196 KapuriyaRahul
# 197 Tunez9ja_com
# 198 VoteMDPAnni
# 199 lucchaoui
# 200 GautamSharmaN
# 201 AllsoftGR
# 202 MaurizioMrt
# 203 FrumDiet
# 204 tatty20111
# 205 VenkataGiriapp2
# 206 BhattHarshdip
# 207 Mitsycp
# 208 DavidAnsell19
# 209 Ron_Bourne
# 210 LLa1th
# 211 bragagnimaurizi
# 212 Daily_news__
# 213 NAVARRO_LIVRE
# 214 EduardAmell
# 215 Vicdayz
# 216 Arsaprada
# 217 soulspeek
# 218 cbelive_com
# 219 PUMACUATRO
# 220 d789s101112
# 221 satsahib17
# 222 jiveNcool_it
# 223 flyboy_dinesh
# 224 sentilsebastian
# 225 LFUNDADORES
# 226 chrisabraham
# 227 bookido
# 228 primkray125
# 229 BittleSheila
# 230 DrkNemesis
# 231 SainiJeeti
# 232 topshelfplay
# 233 JasonTheInfamus
# 234 tiancaidingyi
# 235 OgidaSteve
# 236 trabajocontinuo
# 237 daR1Zz0
# 238 ApiAshraf
# 239 aamodMUFC
# 240 by_the_pool
# 241 Matt_Mero
# 242 margotleiser
# 243 nkc47str
# 244 georgebossman
# 245 thinknbewealthy
# 246 Jerel_ME
# 247 athavale_abhi
# 248 KSainathRao1
# 249 Ompohuit
# 250 Y_ActiveCitizen
# 251 24x7Politics
# 252 meetsand
# 253 sarveshAkaruan
# 254 SureshSadagopan
# 255 mmsharma4486
# 256 luizcjr88
# 257 BhattHarshdip
# 258 FoodieMcBooty
# 259 MalenkaWarner
# 260 SkinNclans
# 261 magnifyk
# 262 UPwala_Thakur
# 263 EGuilbrand
# 264 CohanLawPLLC
# 265 jbmagalhaesneto
# 266 AjitHegade
# 267 FundayHerald
# 268 Erick_Martie23
# 269 basildontaxis
# 270 Aamir_mum
# 271 RageOfAFeminist
# 272 ArviJoLOVEU
# 273 Argonaut4
# 274 UPwala_Thakur
# 275 brunbesigye
# 276 rubencantafio
# 277 Merentia
# 278 KuehnMichael
# 279 santu86178454
# 280 nitin07chauhan
# 281 geoscribble
# 282 nawneet_mohan
# 283 _The_Avenue_
# 284 carlita20002000
# 285 me_praty
# 286 walcy_carroll
# 287 saurabhtrivedi1
# 288 rynitw
# 289 Jeno5ide
# 290 Prabhakar2July
# 291 YahyaAbYou
# 292 Kelly_John_son
# 293 Mihanny
# 294 KingJerry146
# 295 SimplyShahriar
# 296 monubadshah2
# 297 MacMMedia
# 298 sont
# 299 blocksteasdy
# 300 Marilyn80s
# 301 alanteles1
# 302 anandcp
# 303 samturpin
# 304 ddanielb1
# 305 arsiusgroup
# 306 Aximum_C
# 307 lewanpantsulaia
# 308 travelgirlbeth
# 309 EBertolaccini
# 310 virat_garg
# 311 strong_girl2012
# 312 rajreddynyc
# 313 MayankSharma079
# 314 paustine0
# 315 mcguirp
# 316 NordicDiplo
# 317 Darth_Giora
# 318 AmiV2
# 319 cotalla41
# 320 income77
# 321 TaxSeminars
# 322 ChocoMusette
# 323 ShuklaSudhir9
# 324 Sassycik
# 325 simple4now
# 326 shekhar19541
# 327 Faryfarhan
# 328 SurendraSrd
# 329 YehAccntFakeHai
# 330 swapnil280617
# 331 TechMashBang
# 332 DilJaanBaloch
# 333 SjSunny83
# 334 MODIfyingBHARAT
# 335 Proud_Hindu_PS
# 336 mannya_123
# 337 DP9JUNE
# 338 contactsujeet1
# 339 deepaksinha_
# 340 deepaksinha_
# 341 ChariiDavid
# 342 GVSURESHBABU
# 343 SurendraSrd
# 344 bge007
# 345 kolAamreV
# 346 payal_choksi
# 347 myunlockar
# 348 GP792
# 349 jewish_indian
# 350 RupeshPMP
# 351 panditzeee
# 352 whoopsoo
# 353 shahnisarg71
# 354 _Anitaraj
# 355 Shankroxx
# 356 vishalvkumar
# 357 sandy7365
# 358 shahnisarg71
# 359 c_bhargava
# 360 DaulatDalimunte
# 361 PrashhDumbre
# 362 Voice_of_Ranjan
# 363 yourshid3
# 364 yadav212
# 365 mishraji_manoj
# 366 apnnewsindia
# 367 Swaps_m2075
# 368 abhijitfloyd
# 369 n_i_k_h_i_l_l
# 370 cpraghav
# 371 reshmarajeev23
# 372 iOnkarPandey
# 373 lingeshgdvg
# 374 Voice_of_Ranjan
# 375 BOBTHEVIPER
# 376 jakanksha92
# 377 shaleen_poddar
# 378 iAvinashSharma
# 379 mayur12dec
# 380 Vijayparadava
# 381 Sandy80772794
# 382 benguism
# 383 imanant27
# 384 perfectindian1
# 385 hiteshkgupta
# 386 rahultri1977
# 387 VishuddhBhartiy
# 388 NationalistOdia
# 389 imanant27
# 390 Abhi14267
# 391 manjujadhav_
# 392 misraashutosh
# 393 krishcarrier
# 394 prithvipatel
# 395 FcKeval
# 396 desiM67690049
# 397 LAKSHMIPRASADV
# 398 UntoldStorY06
# 399 DebDip00
# 400 shashikantsriv8
# 401 hpsneh
# 402 sumit_sm30
# 403 vcv997
# 404 NTKRNow
# 405 surendrapatelsp
# 406 jha_mukesh_
# 407 Karan_Gopalani
# 408 thedevilspeaks
# 409 omikhajuriabjp
# 410 Kashmir_Tiranga
# 411 PEEYUSHRR
# 412 Iam_Praveen1995
# 413 KKannan40
# 414 iAbhishek_J
# 415 Hinduaa_Surya
# 416 captainRDx
# 417 Abdevilliers94
# 418 sacha_hindustan
# 419 VictoryForNamo
# 420 knraina
# 421 AbhinandanAbhis
# 422 wotzwrong
# 423 NaaPaak
# 424 rssnagpur
# 425 PostTruth786
# 426 IGovindSingh
# 427 prakashSriv
# 428 ankushgpt0
# 429 sharmapiyoosh9
# 430 RahulAmida
# 431 nitesh0586
# 432 ashuukr
# 433 ankushgpt0
# 434 bithika11
# 435 sharmapiyoosh9
# 436 being_uppi
# 437 FcKeval
# 438 aakanksha_seth
# 439 jugaljoshi6
# 440 telugu_citizen
# 441 btindian
# 442 keencrack
# 443 SEkalare
# 444 imrakeshkanaik
# 445 bjp_Dodiya
# 446 imhrsabhi
# 447 Mahendr85906058
# 448 aamodMUFC
# 449 bull_shot_69
# 450 sasipassion
# 451 parashuram_PBA
# 452 AmanTha70479765
# 453 VSHARAD0412
# 454 iamkbharathi
# 455 Himansh58652970
# 456 Rahulpathak_31
# 457 Akshayc2727
# 458 bull_shot_69
# 459 YehAccntFakeHai
# 460 A31X64Vijay
# 461 tusharbdas
# 462 Pawan_koradia
# 463 SANJAYGHARMALKA
# 464 Sandy80772794
# 465 Abhi14267
# 466 Bhargav52660860
# 467 lodhi_sunita
# 468 Im_gks
# 469 honestology
# 470 Zee_Hindustan
# wait
# wait
# wait
# wait
# wait

# %%
#retweet

i=1
query="Abu Ismail"
while True:
    try:
        for status in tweepy.Cursor(api.search, q=query).items(): 
            api.retweet(status.id)
            print(i,status.id,status.text)
            n=int(random.uniform(1, 20))
            time.sleep(n)
            i += 1
    except tweepy.TweepError:
        print("wait")
        time.sleep(60 * 15)
        continue
        
    except StopIteration:
        break
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#
# C:\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# C:\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1352         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1353             raise WantReadError()
#    1354         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#
# C:\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# C:\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1352         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1353             raise WantReadError()
#    1354         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#
# C:\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# C:\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1352         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1353             raise WantReadError()
#    1354         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-bb16ce8d2303> in <module>()
#       5 while True:
#       6     try:
# ----> 7         for status in tweepy.Cursor(api.search, q=query).items():
#       8             api.retweet(status.id)
#       9             print(i,status.id,status.text)
#
# C:\Anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# C:\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#     199         self.page_index += 1
#
# C:\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     106
#     107         if self.index >= len(self.results) - 1:
# --> 108             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     109
#     110             if hasattr(self.method, '__self__'):
#
# C:\Anaconda3\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     243             return method
#     244         else:
# --> 245             return method.execute()
#     246
#     247     # Set pagination mode
#
# C:\Anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     185                                                 timeout=self.api.timeout,
#     186                                                 auth=auth,
# --> 187                                                 proxies=self.api.proxy)
#     188                 except Exception as e:
#     189                     raise TweepError('Failed to send request: %s' % e)
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     670
#     671         if not stream:
# --> 672             r.content
#     673
#     674         return r
#
# C:\Anaconda3\lib\site-packages\requests\models.py in content(self)
#     814                 self._content = None
#     815             else:
# --> 816                 self._content = bytes().join(self.iter_content(CONTENT_CHUNK_SIZE)) or bytes()
#     817
#     818         self._content_consumed = True
#
# C:\Anaconda3\lib\site-packages\requests\models.py in generate()
#     736             if hasattr(self.raw, 'stream'):
#     737                 try:
# --> 738                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     739                         yield chunk
#     740                 except ProtocolError as e:
#
# C:\Anaconda3\lib\site-packages\requests\packages\urllib3\response.py in stream(self, amt, decode_content)
#     434         else:
#     435             while not is_fp_closed(self._fp):
# --> 436                 data = self.read(amt=amt, decode_content=decode_content)
#     437
#     438                 if data:
#
# C:\Anaconda3\lib\site-packages\requests\packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# C:\Anaconda3\lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# C:\Anaconda3\lib\http\client.py in readinto(self, b)
#     491         # connection, and the user is reading more bytes than will be provided
#     492         # (for example, reading in 1k chunks)
# --> 493         n = self.fp.readinto(b)
#     494         if not n and b:
#     495             # Ideally, we would raise IncompleteRead if the content-length
#
# C:\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# C:\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     291                 raise timeout('The read operation timed out')
#     292             else:
# --> 293                 return self.recv_into(*args, **kwargs)
#     294
#     295     def settimeout(self, timeout):
#
# C:\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     291                 raise timeout('The read operation timed out')
#     292             else:
# --> 293                 return self.recv_into(*args, **kwargs)
#     294
#     295     def settimeout(self, timeout):
#
# C:\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     287                 raise
#     288         except OpenSSL.SSL.WantReadError:
# --> 289             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     290             if not rd:
#     291                 raise timeout('The read operation timed out')
#
# C:\Anaconda3\lib\site-packages\requests\packages\urllib3\util\wait.py in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# C:\Anaconda3\lib\site-packages\requests\packages\urllib3\util\wait.py in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# C:\Anaconda3\lib\site-packages\requests\packages\urllib3\util\selectors.py in select(self, timeout)
#     318             ready = []
#     319             r, w, _ = _syscall_wrapper(self._select, True, self._readers,
# --> 320                                        self._writers, timeout)
#     321             r = set(r)
#     322             w = set(w)
#
# C:\Anaconda3\lib\site-packages\requests\packages\urllib3\util\selectors.py in _syscall_wrapper(func, _, *args, **kwargs)
#      62         and recalculate their timeouts. """
#      63         try:
# ---> 64             return func(*args, **kwargs)
#      65         except (OSError, IOError, select.error) as e:
#      66             errcode = None
#
# C:\Anaconda3\lib\site-packages\requests\packages\urllib3\util\selectors.py in _select(self, r, w, timeout)
#     308         def _select(self, r, w, timeout=None):
#     309             """ Wrapper for select.select because timeout is a positional arg """
# --> 310             return select.select(r, w, [], timeout)
#     311
#     312         def select(self, timeout=None):
#
# KeyboardInterrupt:

# %%
t.mutes.users.create(user_id=user_id)
